# %% [markdown]
# <a href="https://colab.research.google.com/github/OmdenaAI/hyderabad-india-chapter-patients-chatbot/blob/main/src/tasks/task-1-webscraping/Merge_web_scrapped_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 50)

# %%
df_diabetes = pd.read_csv('/content/Diabetes_Final.csv')
df_diarrhea = pd.read_csv(r'/content/Diarrheal diseases.csv', encoding='latin-1')
df_Respiratory_Upper_lower_infection = pd.read_csv('/content/Respiratory_Upper_lower_infection.csv', encoding='latin-1')
df_covid = pd.read_csv('/content/covid.csv')
df_dengue = pd.read_csv('/content/dengue.csv')
df_heart_diseases = pd.read_csv('/content/heart_diseases.csv',  encoding='latin-1')

# %%
df_diabetes['condition'] = 'diabetes'
df_diarrhea['condition'] = 'diarrhea'
df_Respiratory_Upper_lower_infection['condition'] = 'respiratory infection'
df_covid['condition'] = 'covid'
df_dengue['condition'] = 'dengue'
df_heart_diseases['condition'] = 'heart diseases'

df_diabetes.head()
# Out:
#                             Symptoms(common) Symptoms(babies/infants)  \
# 0                           Increased thirst                      NaN
# 1                     Weak and tired feeling                      NaN
# 2                             Blurred vision                      NaN
# 3  Numbness or tingling in the hands or feet                      NaN
# 4                 Slow-healing sores or cuts                      NaN
#
#    Symptoms(old people)              Symptoms(male)  \
# 0                   NaN         Decreased sex drive
# 1                   NaN        Erectile dysfunction
# 2                   NaN  Decreased muscle strength.
# 3                   NaN                         NaN
# 4                   NaN                         NaN
#
#                                     Symptoms(female)  \
# 0                                 Dry and itchy skin
# 1  Frequent yeast infections or urinary tract inf...
# 2                                 Frequent urination
# ...

# %%
merged_df = pd.concat([df_diabetes, df_diarrhea, df_Respiratory_Upper_lower_infection, df_covid, df_dengue, df_heart_diseases], ignore_index=True, sort=False)
merged_df.head()
# Out:
#                             Symptoms(common) Symptoms(babies/infants)  \
# 0                           Increased thirst                      NaN
# 1                     Weak and tired feeling                      NaN
# 2                             Blurred vision                      NaN
# 3  Numbness or tingling in the hands or feet                      NaN
# 4                 Slow-healing sores or cuts                      NaN
#
#   Symptoms(old people)              Symptoms(male)  \
# 0                  NaN         Decreased sex drive
# 1                  NaN        Erectile dysfunction
# 2                  NaN  Decreased muscle strength.
# 3                  NaN                         NaN
# 4                  NaN                         NaN
#
#                                     Symptoms(female)  \
# 0                                 Dry and itchy skin
# 1  Frequent yeast infections or urinary tract inf...
# 2                                 Frequent urination
# ...

# %%
merged_df.to_csv('merged_data.csv', index = False)
